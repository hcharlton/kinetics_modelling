# %%
from kinetics_modelling.config import PROCESSED_DATA_DIR
import polars as pl
import altair as alt
alt.data_transformers.enable("vegafusion")

pl.Config(fmt_str_lengths=100)
# Out:
# 2025-04-04 09:01:06.164 | INFO     | kinetics_modelling.config:<module>:12 - PROJ_ROOT path is: /faststorage/project/mutationalscanning/Workspaces/chcharlton/kinetics_modelling

# %%
q = (
    pl.scan_parquet(PROCESSED_DATA_DIR / 'ob006-run2_full')
    .head()
)
q.collect()
# Out:
# shape: (5, 27)
# ┌────────────┬────────────┬────────────┬─────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ contig     ┆ read_name  ┆ read_is_re ┆ fn  ┆ … ┆ center_sx_ ┆ center_sm_ ┆ center_sm ┆ center_sm │
# │ ---        ┆ ---        ┆ verse      ┆ --- ┆   ┆ 2          ┆ 0          ┆ _1        ┆ _2        │
# │ str        ┆ str        ┆ ---        ┆ i64 ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆ bool       ┆     ┆   ┆ u8         ┆ u8         ┆ u8        ┆ u8        │
# ╞════════════╪════════════╪════════════╪═════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ h1tg000001 ┆ m84108_240 ┆ false      ┆ 5   ┆ … ┆ 1          ┆ 10         ┆ 8         ┆ 9         │
# │ l          ┆ 530_140750 ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ _s2/736637 ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# ...

# %%
Read name = m84108_240530_160720_s3/57150815/ccs
Sample = 22_113_OB006_V
Library = 22_113_OB006_V
Read group = a0f19485/25--25
Read length = 12,792 bp
Flags = 0
----------------------
Mapping = Primary @ MAPQ 51
Reference span = h2tg000018l:34,989,396-35,002,193 (+) = 12,798bp
Cigar = 985=1D352=1D488=1D3397=1D4070=1D479=1D3021=
Clipping = None
----------------------
ML = 35,224,230,232,185,255,212,87,5,111,103,85,43,214,45,94,23,68,185,172,12,9,26,253,244,208,130,196,241,100,122,6,179,184,223,145,199,204,7,99,61,112,198,139,152,255,194,13,246,66,92,28,207,206,153,230,4,12,29,252,248,254,155,85,13,41,32,250,204,10,93,251,255,254,131,240,205,249,91,252,216,47,129,255,255,206,79,248,55,254,163,244,200,223,17,171,237,190,180,204,217,244,186,232,253,222,232,238,152,253,221,190,151,38,225,237,136,255,218,84,209,247,228,29,237,158,177,115,189,215,79,245,255,233,234,60,3,69,43,4,49,11,15,35,72,59,89,138,52,18,55,37,2,122,105,255,207,251,149,255,255,251,186,218,93,255,249,157,39,255,254,254,254,255,235,51,52,224,49,149,219,15,95,3,176,203,220,210,219,195,9,15,80,213,255,255,255,255,254,31,206,205,214,37,31,107,56,16,15,62,66

MM = C+m?,35,28,4,3,13,5,4,7,29,14,8,5,22,12,2,11,22,1,6,3,3,6,6,53,22,18,17,22,2,9,5,15,7,5,4,14,12,11,5,12,3,64,9,14,1,2,3,2,0,28,1,9,19,8,2,6,8,2,9,3,11,46,5,34,5,5,5,42,7,4,2,1,0,1,7,5,23,7,4,6,5,7,12,9,1,5,9,2,12,2,52,31,25,1,16,19,21,54,2,16,14,77,50,4,6,1,8,6,16,6,15,12,4,8,14,67,9,3,26,29,9,22,23,8,5,2,31,28,64,67,9,7,26,8,12,49,14,2,7,15,1,9,76,9,9,1,11,7,2,0,3,1,25,39,2,11,14,6,8,17,1,114,66,11,11,48,1,8,2,7,0,0,6,2,3,7,0,1,26,7,17,2,7,13,28,0,22,25,2,22,29,7,3,27,34,2,5,0,2,4,2,19,11,10,3,6,16,11,6,6,9;
NM = 6
ma = 0
sa = [not shown]

ac = [not shown]

bc = [not shown]

ec = 8.499228
mc = 99.953094
qe = 12808
we = 10796967
mg = 99.95312
fi = [not shown]

ri = [not shown]

bl = CAGTAGCGTCGAGTAT
ql = ~xn~~o\e}rezp~k~
sm = [not shown]

zm = 57150815
fn = 3
rn = 4
sn = [not shown]

fp = [not shown]

np = 7
rp = [not shown]

bq = 100
rq = 0.99970955
ls = [not shown]

qs = 16
ws = 36977
bt = ATACTCGACGCTACTG
qt = ~zsdn??~]_o~~n~~
bx = [not shown]

cx = 12
sx = [not shown]

Hidden tags: RG
------------------
Location = h2tg000018l:35,001,722
Base = A @ QV 93
----------------------

Read sequence = ...

Orig sequence = ...
